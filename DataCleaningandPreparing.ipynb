# %%
import pandas as pd

# %%
movies = pd.read_csv("movies.csv")

# %%
movies
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky        -2021
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves        -2021
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
df = movies.copy()

# %%
#1. Dropping duplicates

# %%
df = df.drop_duplicates()

# %%
#df contains 9868 rows now

# %%
df.tail(20)
# Out:
#                           MOVIES         YEAR  \
# 9960                      Sexify     (2021– )
# 9961                      Sexify     (2021– )
# 9962                      Sexify     (2021– )
# 9963                 Castlevania  (2017–2021)
# 9964   AlRawabi School for Girls        -2021
# 9965   AlRawabi School for Girls        -2021
# 9966   AlRawabi School for Girls        -2021
# 9967   AlRawabi School for Girls        -2021
# 9975                    Ultraman     (2019– )
# 9976                    The Talk     (2010– )
# 9979           Never Have I Ever     (2020– )
# 9980                        1899     (2022– )
# 9983            The Last Kingdom     (2015– )
# 9986            The Last Kingdom     (2015– )
# 9987            The Last Kingdom     (2015– )
# 9993                   Totenfrau     (2022– )
# 9995                      Arcane     (2021– )
# 9996           Heart of Invictus     (2022– )
# 9997              The Imperfects     (2021– )
# ...

# %%
df.loc[9997,"STARS"]
# Out:
# '\n    Director:\nJovanka Vuckovic\n| \n    Stars:\nMorgan Taylor Campbell, \nIñaki Godoy, \nRhianna Jagpal, \nSiddhartha Minhas\n'

# %%
df.loc[9998,"STARS"]
# Out:
# '\n    Director:\nJovanka Vuckovic\n| \n    Stars:\nMorgan Taylor Campbell, \nJennifer Cheon Garcia, \nIñaki Godoy, \nRhianna Jagpal\n'

# %%
#lot of near duplicates . we will handle it at last.now  we correct data column wise

# %%
#changing column names for ease of use

# %%
df.columns = ["name","year","genre","rating","description","stars","votes","runtime","gross"]

# %%
df.head(1)
# Out:
#             name   year                                   genre  rating  \
# 0  Blood Red Sky  -2021  \nAction, Horror, Thriller                 6.1
#
#                                          description  \
# 0  \nA woman with a mysterious illness is forced ...
#
#                                                stars   votes  runtime gross
# 0  \n    Director:\nPeter Thorwarth\n| \n    Star...  21,062    121.0   NaN

# %%
#1st column name

# %%
#seems okay

# %%
#2nd column year

# %%
df["year"]
# Out:
# 0             -2021
# 1          (2021– )
# 2       (2010–2022)
# 3          (2013– )
# 4             -2021
#            ...
# 9993       (2022– )
# 9995       (2021– )
# 9996       (2022– )
# 9997       (2021– )
# 9998       (2021– )
# Name: year, Length: 9568, dtype: object

# %%
df["year"] = df["year"].str.strip().str.replace(")","").str.replace("(","").str.replace("-","")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18644\2047906786.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["year"] = df["year"].str.strip().str.replace(")","").str.replace("(","").str.replace("-","")

# %%
df["year"]
# Out:
# 0            2021
# 1          2021–
# 2       2010–2022
# 3          2013–
# 4            2021
#           ...
# 9993       2022–
# 9995       2021–
# 9996       2022–
# 9997       2021–
# 9998       2021–
# Name: year, Length: 9568, dtype: object

# %%
#- is not removing, not - perhaps other charachter

# %%
def removegarbage(year):
    result = ""
    for g in year: 
        if g.isdigit():
            result += g
    return result

# %%
a = "223g"

# %%
removegarbage(a)
# Out:
# '223'

# %%
#float  object is not iterable

# %%
df["year"] = df["year"].astype("str")

# %%
df["year"] = df["year"].apply(removegarbage)

# %%
df["year"]
# Out:
# 0           2021
# 1           2021
# 2       20102022
# 3           2013
# 4           2021
#           ...
# 9993        2022
# 9995        2021
# 9996        2022
# 9997        2021
# 9998        2021
# Name: year, Length: 9568, dtype: object

# %%
df["year"].str.strip()
# Out:
# 0           2021
# 1           2021
# 2       20102022
# 3           2013
# 4           2021
#           ...
# 9993        2022
# 9995        2021
# 9996        2022
# 9997        2021
# 9998        2021
# Name: year, Length: 9568, dtype: object

# %%
#for year values as range

# %%
def adddash(year):
    a =""
    b =""
    if len(year)==8:
        a = year[0:4]
        b = year[4:8]
        return (a+"-"+b)
    else:
        return year

# %%
b = "12349876"

# %%
c = "3342"

# %%
adddash(c)
# Out:
# '3342'

# %%
adddash(b)
# Out:
# '1234-9876'

# %%
df["year"] = df["year"].apply(adddash)

# %%
years = pd.DataFrame(df["year"].value_counts())

# %%
years
# Out:
#            year
# 2020       1622
# 2019       1124
# 2021        987
# 2018        861
# 2017        664
# ...         ...
# 2008-2020     1
# 1984-1996     1
# 1975-1979     1
# 2002-2019     1
# 2004-2009     1
#
# [233 rows x 1 columns]

# %%
##there is a missing value as space in year

# %%
years.to_csv("years.csv")

# %%
df.loc[df["year"]=="","year"] = 9999

# %%
df.loc[df["year"]== 9999]
# Out:
#                    name  year                                   genre  rating  \
# 878   Vikings: Valhalla  9999  \nAction, Adventure, Drama                 NaN
# 1155         The Killer  9999      \nAction, Crime, Drama                 NaN
# 1165             Hustle  9999      \nComedy, Drama, Sport                 NaN
# 1375      Resident Evil  9999    \nAction, Horror, Sci-Fi                 NaN
# 1414           Bright 2  9999  \nAction, Adventure, Crime                 NaN
# ...                 ...   ...                                     ...     ...
# 9904       Pretty Smart  9999                    \nComedy                 NaN
# 9907       Pretty Smart  9999                    \nComedy                 NaN
# 9908       Pretty Smart  9999                    \nComedy                 NaN
# 9909       Pretty Smart  9999                    \nComedy                 NaN
# 9910       Pretty Smart  9999                    \nComedy                 NaN
#
# ...

# %%
# cant change to date time due to range of years

# %%
df
# Out:
#                                      name       year  \
# 0                           Blood Red Sky       2021
# 1     Masters of the Universe: Revelation       2021
# 2                        The Walking Dead  2010-2022
# 3                          Rick and Morty       2013
# 4                         Army of Thieves       2021
# ...                                   ...        ...
# 9993                            Totenfrau       2022
# 9995                               Arcane       2021
# 9996                    Heart of Invictus       2022
# 9997                       The Imperfects       2021
# 9998                       The Imperfects       2021
#
#                                            genre  rating  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# 3     \nAnimation, Adventure, Comedy                 9.2
# ...

# %%
df["genre"] = df["genre"].str.replace("\n","").str.strip()

# %%
df["description"] = df["description"].str.replace("\n","").str.strip()

# %%
df["stars"] = df["stars"].str.replace("\n","").str.strip()

# %%
df["rating"] = df["rating"].fillna("no rating")

# %%
df["votes"] = df["votes"].fillna("no votes")

# %%
df["runtime"] = df["runtime"].fillna("no runtime")

# %%
df["gross"] = df["gross"].fillna("no gross")

# %%
df
# Out:
#                                      name       year  \
# 0                           Blood Red Sky       2021
# 1     Masters of the Universe: Revelation       2021
# 2                        The Walking Dead  2010-2022
# 3                          Rick and Morty       2013
# 4                         Army of Thieves       2021
# ...                                   ...        ...
# 9993                            Totenfrau       2022
# 9995                               Arcane       2021
# 9996                    Heart of Invictus       2022
# 9997                       The Imperfects       2021
# 9998                       The Imperfects       2021
#
#                              genre     rating  \
# 0         Action, Horror, Thriller        6.1
# 1     Animation, Action, Adventure        5.0
# 2          Drama, Horror, Thriller        8.2
# 3     Animation, Adventure, Comedy        9.2
# 4            Action, Crime, Horror  no rating
# ...

# %%
def director(stars):
    result =""
    if "|" in stars:
        result = stars.split("|")
        return result[0]
    else:
        return result

# %%
a = "Director :sadafaf | stars:asdasd"

# %%
b =  "stars:asdasd"

# %%
director(a)
# Out:
# 'Director :sadafaf '

# %%
director(b)
# Out:
# ''

# %%
df["stars"].apply(director)
# Out:
# 0             Director:Peter Thorwarth
# 1
# 2
# 3
# 4       Director:Matthias Schweighöfer
#                      ...
# 9993            Director:Nicolai Rohde
# 9995
# 9996    Director:Orlando von Einsiedel
# 9997         Director:Jovanka Vuckovic
# 9998         Director:Jovanka Vuckovic
# Name: stars, Length: 9568, dtype: object

# %%
df.insert(loc=5,column="director",value= df["stars"].apply(director))

# %%
df
# Out:
#                                      name       year  \
# 0                           Blood Red Sky       2021
# 1     Masters of the Universe: Revelation       2021
# 2                        The Walking Dead  2010-2022
# 3                          Rick and Morty       2013
# 4                         Army of Thieves       2021
# ...                                   ...        ...
# 9993                            Totenfrau       2022
# 9995                               Arcane       2021
# 9996                    Heart of Invictus       2022
# 9997                       The Imperfects       2021
# 9998                       The Imperfects       2021
#
#                              genre     rating  \
# 0         Action, Horror, Thriller        6.1
# 1     Animation, Action, Adventure        5.0
# 2          Drama, Horror, Thriller        8.2
# 3     Animation, Adventure, Comedy        9.2
# 4            Action, Crime, Horror  no rating
# ...

# %%
def star(stars):
    result =""
    if "|" in stars:
        result = stars.split("|")
        return result[1]
    else:
        return result

# %%
a = "Director :sadafaf | stars:asdasd"

# %%
df["stars"] = df["stars"].apply(star)

# %%
df
# Out:
#                                      name       year  \
# 0                           Blood Red Sky       2021
# 1     Masters of the Universe: Revelation       2021
# 2                        The Walking Dead  2010-2022
# 3                          Rick and Morty       2013
# 4                         Army of Thieves       2021
# ...                                   ...        ...
# 9993                            Totenfrau       2022
# 9995                               Arcane       2021
# 9996                    Heart of Invictus       2022
# 9997                       The Imperfects       2021
# 9998                       The Imperfects       2021
#
#                              genre     rating  \
# 0         Action, Horror, Thriller        6.1
# 1     Animation, Action, Adventure        5.0
# 2          Drama, Horror, Thriller        8.2
# 3     Animation, Adventure, Comedy        9.2
# 4            Action, Crime, Horror  no rating
# ...

# %%
df["director"].str.split(":")
# Out:
# 0             [Director, Peter Thorwarth]
# 1                                      []
# 2                                      []
# 3                                      []
# 4       [Director, Matthias Schweighöfer]
#                       ...
# 9993            [Director, Nicolai Rohde]
# 9995                                   []
# 9996    [Director, Orlando von Einsiedel]
# 9997         [Director, Jovanka Vuckovic]
# 9998         [Director, Jovanka Vuckovic]
# Name: director, Length: 9568, dtype: object

# %%
def director_name_only(dir):
    result = ""
    if ":" in dir:
        result = dir.split(":")
        return result[1]
    else:
        result ="director not listed"
        return result

# %%
a = "director:qeqweq"

# %%
director_name_only(a)
# Out:
# 'qeqweq'

# %%
b = "asdasd"

# %%
director_name_only(b)
# Out:
# 'director not listed'

# %%
df["director"]  = df["director"].apply(director_name_only)

# %%
df
# Out:
#                                      name       year  \
# 0                           Blood Red Sky       2021
# 1     Masters of the Universe: Revelation       2021
# 2                        The Walking Dead  2010-2022
# 3                          Rick and Morty       2013
# 4                         Army of Thieves       2021
# ...                                   ...        ...
# 9993                            Totenfrau       2022
# 9995                               Arcane       2021
# 9996                    Heart of Invictus       2022
# 9997                       The Imperfects       2021
# 9998                       The Imperfects       2021
#
#                              genre     rating  \
# 0         Action, Horror, Thriller        6.1
# 1     Animation, Action, Adventure        5.0
# 2          Drama, Horror, Thriller        8.2
# 3     Animation, Adventure, Comedy        9.2
# 4            Action, Crime, Horror  no rating
# ...

# %%
 def star_name_only(star):
    result = ""
    if ":" in star:
        result = star.split(":")
        return result[1]
    else:
        result ="star not listed"
        return result

# %%
df["stars"] = df["stars"].apply(star_name_only)

# %%
df
# Out:
#                                      name       year  \
# 0                           Blood Red Sky       2021
# 1     Masters of the Universe: Revelation       2021
# 2                        The Walking Dead  2010-2022
# 3                          Rick and Morty       2013
# 4                         Army of Thieves       2021
# ...                                   ...        ...
# 9993                            Totenfrau       2022
# 9995                               Arcane       2021
# 9996                    Heart of Invictus       2022
# 9997                       The Imperfects       2021
# 9998                       The Imperfects       2021
#
#                              genre     rating  \
# 0         Action, Horror, Thriller        6.1
# 1     Animation, Action, Adventure        5.0
# 2          Drama, Horror, Thriller        8.2
# 3     Animation, Adventure, Comedy        9.2
# 4            Action, Crime, Horror  no rating
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9568 entries, 0 to 9998
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         9568 non-null   object
#  1   year         9568 non-null   object
#  2   genre        9490 non-null   object
#  3   rating       9568 non-null   object
#  4   description  9568 non-null   object
#  5   director     9568 non-null   object
#  6   stars        9568 non-null   object
#  7   votes        9568 non-null   object
#  8   runtime      9568 non-null   object
#  9   gross        9568 non-null   object
# dtypes: object(10)
# memory usage: 1.1+ MB

# %%
df.to_csv("df.csv")
